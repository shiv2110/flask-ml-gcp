# %%
from pycaret.regression import *
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Data.csv')

# %%
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0  14.96  41.76  1024.07  73.17  463.26
# 1  25.18  62.96  1020.04  59.08  444.37
# 2   5.11  39.40  1012.16  92.14  488.56
# 3  20.86  57.32  1010.24  76.64  446.48
# 4  10.82  37.50  1009.23  96.62  473.90

# %%
reg = setup(df, target = 'PE')
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style><table id="T_be8465ae_ca78_11ea_8910_809133689df6" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_be8465ae_ca78_11ea_8910_809133689df6level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_be8465ae_ca78_11ea_8910_809133689df6row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_be8465ae_ca78_11ea_8910_809133689df6row0_col1" class="data row0 col1" >2458</td>
#             </tr>
#             <tr>
#                         <th id="T_be8465ae_ca78_11ea_8910_809133689df6level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_be8465ae_ca78_11ea_8910_809133689df6row1_col0" class="data row1 col0" >Transform Target </td>
# ...

# %%
rf = create_model('rf')
# Out:
#          MAE      MSE    RMSE      R2   RMSLE    MAPE
# 0     2.4464  12.3442  3.5134  0.9537  0.0077  0.0054
# 1     2.2943   9.9064  3.1474  0.9671  0.0069  0.0051
# 2     2.3884  10.5480  3.2478  0.9643  0.0072  0.0053
# 3     2.5177  14.1835  3.7661  0.9503  0.0082  0.0056
# 4     2.3319   9.8249  3.1345  0.9676  0.0069  0.0051
# 5     2.3789  10.2228  3.1973  0.9643  0.0070  0.0052
# 6     2.4042   9.9189  3.1494  0.9672  0.0069  0.0053
# 7     2.2689   9.0057  3.0010  0.9667  0.0066  0.0050
# 8     2.4691  11.7504  3.4279  0.9608  0.0075  0.0054
# 9     2.3799  11.1117  3.3334  0.9601  0.0073  0.0052
# Mean  2.3880  10.8816  3.2918  0.9622  0.0072  0.0053
# SD    0.0730   1.4459  0.2135  0.0057  0.0005  0.0002

# %%
plot_model(rf)

# %%
save_model(rf, 'deployment_20072020')
# Out:
# Transformation Pipeline and Model Succesfully Saved
